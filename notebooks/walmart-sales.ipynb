# %%
import numpy as np
import pandas as pd
import sklearn
import matplotlib as mpl
import matplotlib.pyplot as plt
import math
import sklearn

# %%
# Functions
from sklearn.model_selection import train_test_split
from sklearn.experimental import enable_halving_search_cv
# Tools
from sklearn.model_selection import HalvingRandomSearchCV
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.metrics import r2_score
from sklearn.base import BaseEstimator, TransformerMixin

# ML Models
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import Normalizer
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso

# %%
# get the data
features_df=pd.read_csv('data/features.csv')
store_df=pd.read_csv('data/stores.csv')
sales_df=pd.read_csv('data/train.csv')

# %% [markdown]
# # first look at how the data is stored

# %%
print(features_df.info(),store_df.info(),sales_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8190 entries, 0 to 8189
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Store         8190 non-null   int64
#  1   Date          8190 non-null   object
#  2   Temperature   8190 non-null   float64
#  3   Fuel_Price    8190 non-null   float64
#  4   MarkDown1     4032 non-null   float64
#  5   MarkDown2     2921 non-null   float64
#  6   MarkDown3     3613 non-null   float64
#  7   MarkDown4     3464 non-null   float64
#  8   MarkDown5     4050 non-null   float64
#  9   CPI           7605 non-null   float64
#  10  Unemployment  7605 non-null   float64
#  11  IsHoliday     8190 non-null   bool
# dtypes: bool(1), float64(9), int64(1), object(1)
# memory usage: 712.0+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Store   45 non-null     int64
#  1   Type    45 non-null     object
#  2   Size    45 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 1.2+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421570 entries, 0 to 421569
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
# dtypes: bool(1), float64(1), int64(2), object(1)
# memory usage: 13.3+ MB
# None None None

# %%
features_df["Date"] = pd.to_datetime(features_df["Date"])
sales_df["Date"] = pd.to_datetime(sales_df["Date"])
#we cant test\train on data later than 2012-10-26 so for this excersize it is useless
last_Date = sales_df.Date.max()
features_df = features_df[features_df["Date"]<=last_Date]

# %%
features_df.MarkDown5.value_counts(dropna=False)
#seems like theres no 0's in MarkDowns so we wont lose any information turning Nan into 0's but is it the right choice
# Out:
# NaN        4140
# 1064.56       2
# 2743.18       2
# 492.36        1
# 755.80        1
#            ...
# 3154.77       1
# 1941.32       1
# 2862.32       1
# 1610.18       1
# 858.33        1
# Name: MarkDown5, Length: 2294, dtype: int64

# %%
features_df["isNAn"] = features_df["MarkDown4"].isna()
#we will take MarkDown4 as a sample since the Data in other MarkDowns is similiar on other MarkDown columns

# %%
fig, ax = plt.subplots() 
for i in [1,2,3,4,5]:
    features_df["isNAn"] = features_df["MarkDown" + str(i)].isna()
    #fig, ax = plt.subplots()
    ax.plot(features_df.groupby("Date").isNAn.agg("mean"))

# %%
fig, ax = plt.subplots() 
ax.plot(features_df.groupby("Date").isNAn.agg("mean"))
#seems like they started tracking the markdowns only from a certain date thus 0 doesnt have a particular meaning 
#either take average markdown or not use markdowns(not ideal)
#if theres hope to get more markdown Data at the fututre to train on we would have used it but this time its better to use more data

# %%
#drop markdowns
markdowns = ["MarkDown1","MarkDown2","MarkDown3","MarkDown4","MarkDown5",]
features_df = features_df.drop (columns = markdowns)

# %% [markdown]
# **after doing immediate changes we will merge our data into one table**

# %%
#first look at sales_df departments
fig, ax = plt.subplots() 
ax.plot(sales_df.groupby("Store").Dept.agg("nunique"))
#we can see not all stores have the same number or even the same departments
#we would want to predict the sales in each department

# %%
df = pd.merge(sales_df,features_df,how="outer",on=["Store","Date"])
df = pd.merge(df,store_df,how="outer",on=["Store"])
df=df.drop(columns=["isNAn"])

# %% [markdown]
# # first look at our data

# %%
df.head(10)
# Out:
#    Store  Dept       Date  Weekly_Sales  IsHoliday_x  Temperature  Fuel_Price  \
# 0      1     1 2010-02-05      24924.50        False        42.31       2.572
# 1      1     2 2010-02-05      50605.27        False        42.31       2.572
# 2      1     3 2010-02-05      13740.12        False        42.31       2.572
# 3      1     4 2010-02-05      39954.04        False        42.31       2.572
# 4      1     5 2010-02-05      32229.38        False        42.31       2.572
# 5      1     6 2010-02-05       5749.03        False        42.31       2.572
# 6      1     7 2010-02-05      21084.08        False        42.31       2.572
# 7      1     8 2010-02-05      40129.01        False        42.31       2.572
# 8      1     9 2010-02-05      16930.99        False        42.31       2.572
# 9      1    10 2010-02-05      30721.50        False        42.31       2.572
#
#           CPI  Unemployment  IsHoliday_y Type    Size
# 0  211.096358         8.106        False    A  151315
# 1  211.096358         8.106        False    A  151315
# 2  211.096358         8.106        False    A  151315
# 3  211.096358         8.106        False    A  151315
# 4  211.096358         8.106        False    A  151315
# 5  211.096358         8.106        False    A  151315
# 6  211.096358         8.106        False    A  151315
# 7  211.096358         8.106        False    A  151315
# 8  211.096358         8.106        False    A  151315
# 9  211.096358         8.106        False    A  151315

# %% [raw]
# df.describe()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 12 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  datetime64[ns]
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday_x   421570 non-null  bool
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   CPI           421570 non-null  float64
#  8   Unemployment  421570 non-null  float64
#  9   IsHoliday_y   421570 non-null  bool
#  10  Type          421570 non-null  object
#  11  Size          421570 non-null  int64
# dtypes: bool(2), datetime64[ns](1), float64(5), int64(3), object(1)
# memory usage: 36.2+ MB

# %%
df = df.drop(columns = ["IsHoliday_y"])
df.rename(columns={"IsHoliday_x":"IsHoliday"},inplace=True)

# %%
df[df["Weekly_Sales"]<0].Weekly_Sales.describe()
#looks like the sales are not a typo mistake but actual losses
# Out:
# count    1285.000000
# mean      -68.608218
# std       231.664245
# min     -4988.940000
# 25%       -41.000000
# 50%       -13.200000
# 75%        -4.940000
# max        -0.020000
# Name: Weekly_Sales, dtype: float64

# %%
multi_index_df=df.set_index(["Date","Store","Dept"]).sort_index()

# %%
multi_index_df.groupby(level=[1,2]).shift(1)
#not in final product, just an example of how to work with multi index
df.columns
# Out:
# Index(['Store', 'Dept', 'Date', 'Weekly_Sales', 'IsHoliday', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment', 'Type', 'Size'],
#       dtype='object')

# %%
columns=['Weekly_Sales', 'IsHoliday', 'Temperature',
       'Fuel_Price', 'CPI', 'Unemployment']
for column in columns:
    multi_index_df["Last_Week_"+column]=multi_index_df.groupby(level=[1,2])[column].shift(1)

# %%
 multi_index_df["Is_next_Week_Holiday"]=multi_index_df.groupby(level=[1,2])["IsHoliday"].shift(-1)

# %%
#doesnt work, sunk cost fallacy wouldnt get me
#our regular way is exposed to edge cases due to being by index but pandas refuses to be normal with time index and multi index  
# def rolling_time(ser: pd.Series):
#     ser=ser.reset_index().set_index("Date")
#     store=ser["Store"][0]
#     ser[store]=ser[store].rolling("21D").mean()
#     return ser
# multi_index_df.groupby(level=[1,2])["Weekly_Sales"].apply(lambda x :rolling_time(x))

# %%
columns = ['Weekly_Sales', 'Temperature',
       'Fuel_Price', 'CPI', 'Unemployment']
for column in columns:
    multi_index_df["rolling_Mean_"+column]=multi_index_df.groupby(level=[1,2])["Last_Week_"+column].apply(lambda x :x.rolling(5).mean())

# %%
columns = [ 'Last_Week_Weekly_Sales', 
       'Last_Week_Fuel_Price', 'Last_Week_CPI', 'Last_Week_Unemployment']
multi_index_df = multi_index_df.drop(columns=columns)

# %%
#start visualization 
#
target_column="Weekly_Sales"
countable_columns= [
    "IsHoliday","Type","Is_next_Week_Holiday","Last_Week_IsHoliday"
]
uncountable_columns= [
    'Temperature', 'Fuel_Price', 'CPI',
       'Unemployment',  'Size', 
        'Last_Week_Temperature', 
       'rolling_Mean_Weekly_Sales', 
       'rolling_Mean_Temperature', 'rolling_Mean_Fuel_Price',
       'rolling_Mean_CPI', 'rolling_Mean_Unemployment'
]

legend_colors = ['tab:blue', 'tab:orange']

# Config columns names
target_column_label = "Weekly_Sales"

# %%
def disply_atter_per_column(inedexs: list, values: list, columns_label: list):
    global legend_colors, target_column, target_column_label
    
    # Main elements    
    fig = plt.figure(figsize = [16, 8])
        
    for i in range(len(values)):        
        value = values[i]
        if value is not None:
            index = indexs[i]
            label = columns_label[i]
            
            # Graf
            ax_graf =  fig.add_subplot(1, len(values), i+1)
            
            plt.sca(ax_graf)
            plt.plot(index, value)
            plt.xlabel(label)
            plt.ylabel(target_column_label)
            
    plt.show()

# %%
def disply_multi_bars(inedexs: list, values: list, indexs_label, values_label, elements_in_line: int):
    global legend_colors
    
    values += np.full(elements_in_line-len(values)%elements_in_line, None).tolist()
    inedexs += np.full(elements_in_line-len(values)%elements_in_line, None).tolist()
    
    h = int(len(values) / elements_in_line)
    
    # Main elements 
    fig = plt.figure(figsize = [16, h * 8])
    
    gs = fig.add_gridspec(h, elements_in_line)
    
    line = 0
    while len(values) > 0:
        now_values = values[:elements_in_line]
        now_inedexs = inedexs[:elements_in_line]
                
        for i in range(elements_in_line):        
            value = now_values[i]
            if value is not None:
                index = now_inedexs[i]
                value = now_values[i]
            
                index_label = indexs_label
                value_label = values_label
                if type(indexs_label) == list:
                    index_label = indexs_label[i]
            
                if type(values_label) == list:
                    value_label = values_label[i]
            
                # Graf
                ax_graf = fig.add_subplot(gs[line, i])
        
                plt.sca(ax_graf)
                plt.bar(index, value)
                plt.xlabel(index_label)
                plt.ylabel(value_label)
                
        values = values[elements_in_line:]
        inedexs = inedexs[elements_in_line:]
        
        if type(indexs_label) == list:
            indexs_label = indexs_label[elements_in_line:]
            
        if type(values_label) == list:
            values_label = values_label[elements_in_line:]
        
        line += 1
    
    plt.show()

# %%
printed_columns = countable_columns  
elements_in_line = 3
indexs = []
values = []
for column in printed_columns:
    if column is not None:
        count_df = multi_index_df[[target_column, column]].groupby([column]).count()

        indexs += [count_df.index]
        values += [count_df[target_column].values.tolist()]            

disply_multi_bars(indexs, values, printed_columns, 'count', elements_in_line)

# %%
printed_columns = countable_columns  
elements_in_line = 3
indexs = []
values = []
for column in printed_columns:
    if column is not None:
        mean_df = multi_index_df[[target_column, column]].groupby([column]).mean()

        indexs += [mean_df.index]
        values += [mean_df[target_column].values.tolist()]            

disply_multi_bars(indexs, values, printed_columns, 'count', elements_in_line)

# %%
sections=60
atter_name = 'mean'
elements_in_line = 2
printed_columns = uncountable_columns

printed_columns += np.full(elements_in_line-len(printed_columns)%elements_in_line, None).tolist()
while len(printed_columns) > 0:
    now_columns = printed_columns[:elements_in_line]
    indexs = []
    values = []
    for column in now_columns:
        if column is None:
            indexs += [None]
            values += [None]
        else:
            new_df = multi_index_df[[target_column, column]].sort_values(column)
            length = len(new_df)
            new_df["Sections"] = df.index//(length//sections)
            atter_df = new_df[[target_column, "Sections"]].groupby(["Sections"])
            atter_df = getattr(atter_df, atter_name)()

            indexs += [atter_df.index]
            values += [atter_df[target_column].values]            

    disply_atter_per_column(indexs, values, printed_columns[:elements_in_line])
    printed_columns = printed_columns[elements_in_line:]

# %%
#seems like the main thing that we can get information from is recent sales and size in the countable columns
#to better make sure we need to see 1)the direct effect(not by proportion of data) and 2) compare it to the average weekly sales of the dept

# %%
columns=[
    'Temperature', 'Fuel_Price', 'CPI',
       'Unemployment',
        'Last_Week_Temperature', 'Last_Week_Fuel_Price',
       'Last_Week_CPI', 'Last_Week_Unemployment', 
       'rolling_Mean_Weekly_Sales', 
       'rolling_Mean_Temperature', 'rolling_Mean_Fuel_Price',
       'rolling_Mean_CPI', 'rolling_Mean_Unemployment'
]

# %%
multi_index_df["Normalized_Sales"]= multi_index_df.groupby(level=[1,2])["Weekly_Sales"].transform(lambda x:(x-x.mean())/x.std())

# %%
#
sections=70
atter_name = 'mean'
elements_in_line = 2
printed_columns = uncountable_columns

printed_columns += np.full(elements_in_line-len(printed_columns)%elements_in_line, None).tolist()
while len(printed_columns) > 0:
    now_columns = printed_columns[:elements_in_line]
    indexs = []
    values = []
    for column in now_columns:
        if column is None:
            indexs += [None]
            values += [None]
        else:
            new_df = multi_index_df[["Normalized_Sales", column]].copy().sort_values(column).reset_index()
            new_df.dropna(inplace = True)
            length = len(new_df)
            new_df["Sections"] = new_df.index//(length//sections)
            atter_df = new_df[["Sections", "Normalized_Sales"]].groupby(["Sections"])
           
            atter_df = atter_df.mean()
            indexs += [atter_df.index]
            values += [atter_df["Normalized_Sales"].values]            

    disply_atter_per_column(indexs, values, printed_columns[:elements_in_line])
    printed_columns = printed_columns[elements_in_line:]

# %%
new_df = df[["Weekly_Sales","Date"]]
new_df = new_df.set_index("Date")
new_df.resample("W").mean().plot(figsize = (15, 7), subplots=True, layout=(1, 2) , sharey=True)
# Out:
# array([[<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>]],
#       dtype=object)

# %% [markdown]
# # model part

# %%
model_df = multi_index_df.reset_index().drop(columns=["Normalized_Sales"]).dropna()
def letters(x):
    if(x=="A"):
        return 1
    if(x=="B"):
        return 2
    if(x=="C"):
        return 3
model_df["Type"]= model_df["Type"].apply(lambda x:letters(x))

# %%
model_df["YearEnd"] = False
model_df[(model_df["Date"].dt.month>9) &(model_df["Date"].dt.month<2)]["YearEnd"]=True

# %%
final_test_df = model_df[model_df["Date"]>=pd.Timestamp('2012-09-21T00:00:00.000000000')]
train_df =  model_df[model_df["Date"]<pd.Timestamp('2012-09-21T00:00:00.000000000')]

# %%
X_train,Y_train = train_df.drop(columns=[target_column,"Date"]), train_df[target_column]
X_final_test,Y_final_test = train_df.drop(columns=target_column), train_df[target_column]

# %% [markdown]
# in order to save time and resources we'll test a small amount of data and only after we will run the whole data

# %%
X_train_1,Y_train_1=X_train.head(60000),Y_train.head(60000)

# %% [markdown]
# ### start from a basic model

# %%
class dummy_estimator():
    def __init__(self):
        self.Mean_table = pd.DataFrame()
        self.mean = 0
    def fit(self, x, y):
        self.Mean_table = x.join(y).groupby(["Store","Dept"]).agg({"Weekly_Sales":"mean"})
        self.mean = y.values.mean()
    def predict(self, X):
        def estimated_mean(x):
            if ((x["Store"],x["Dept"]) in  self.Mean_table.index) :
                return self.Mean_table.loc[(x["Store"],x["Dept"])]
            return self.mean
        return X.apply(lambda x:estimated_mean(x) ,axis=1)
    def score (self,X,Y):
        return r2_score(Y,self.predict(X))
estimator = dummy_estimator()
estimator.fit(X_train_1.head(59000) ,Y_train_1.head(59000))
estimator.score(X_train_1.tail(1000),Y_train_1.tail(1000))
# Out:
# 0.9688960189947684

# %%
pipe = Pipeline([("scaler",Normalizer()),("knn",KNeighborsRegressor(10))])
pipe.fit(X_train_1.head(58000),Y_train_1.head(58000))
pipe.score(X_train_1.tail(2000),Y_train_1.tail(2000))
# Out:
# 0.9135584396469062

# %% [markdown]
# looks like we can predict most of the variance by just guessing the average for this specific department

# %% [markdown]
# this is for a  relatively small sample so theres not a lot of different averages for all departments

# %% [markdown]
# we will not realy solely on it but we will add it to the features

# %%
class PreProcessingTranformer(BaseEstimator, TransformerMixin):
    def __init__(self):
        self.Mean_table = pd.DataFrame()
        self.mean = 0
    
    def fit(self, x, y = None):
        print("got here")
        self.Mean_table = x.join(y).groupby(["Store","Dept"]).agg({"Weekly_Sales":"mean"})
        self.mean = y.values.mean()
        return self
    
    def transform(self, X):
        def estimated_mean(x):
            if ((x["Store"],x["Dept"]) in  self.Mean_table.index) :
                return self.Mean_table.loc[(x["Store"],x["Dept"])]
            return self.mean
        X_df = X.copy()
        X_df["estimated Mean"] = X.apply(lambda x:estimated_mean(x) ,axis=1)
        return X_df

steps = [
    ('PreProcessing', PreProcessingTranformer()),
     ("scaler",Normalizer()),
    ("LinReg",LinearRegression(n_jobs = 3))
]
model = Pipeline(steps)

param_grid = {
}

model = RandomizedSearchCV(
    model, param_grid, 
    n_iter = 10,
    cv = 3
)

#model.fit(X_train_1.head(58000),Y_train_1.head(58000))

#model.score(X_train_1.tail(2000),Y_train_1.tail(2000))

# %% [markdown]
# as we can see linear regression doesnt work well at all

# %%
steps = [
    ('PreProcessing', PreProcessingTranformer()),
     ("scaler",Normalizer()),
    ("knn",KNeighborsRegressor())
]
model = Pipeline(steps)

param_grid = {
    "knn__n_neighbors":range(5,25,5)
}
print("gothere")
model = RandomizedSearchCV(
    model, param_grid, 
    cv = 3
)
print("gothere")

model.fit(X_train_1.head(58000),Y_train_1.head(58000))

model.score(X_train_1.tail(2000),Y_train_1.tail(2000))
# Out:
# gothere
# gothere
# got here
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\sklearn\model_selection\_search.py:292: UserWarning: The total space of parameters 4 is smaller than n_iter=10. Running 4 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# got here
# 0.8854670821699048

# %% [markdown]
# knn is far too slow

# %% [markdown]
# and still worse than just guessing the mean of dept and store

# %%
class PreProcessingTranformer(BaseEstimator):
    def __init__(self):
        self.Mean_table = pd.DataFrame()
        self.mean = 0
    
    def fit(self, x, y = None):
        x, y = x.copy(), y.copy()
        self.Mean_table = x.join(y).groupby(["Store","Dept"]).agg({"Weekly_Sales":"mean"})
        self.mean = y.values.mean()
        return self
    
    def transform(self, X):
        def estimated_mean(x):
            if ((x["Store"],x["Dept"]) in  self.Mean_table.index) :
                return self.Mean_table.loc[(x["Store"],x["Dept"])]
            return self.mean
        X_df = X.copy()
        X_df["estimated Mean"] = X.apply(lambda x:estimated_mean(x) ,axis=1)
        drop_col=[]
        X_df.drop(columns=drop_col)
        return X_df
steps = [
    ('PreProcessing', PreProcessingTranformer()),
     ("scaler",Normalizer()),
    ("Lasso",Lasso(warm_start= True))
]
model = Pipeline(steps)

param_grid = {
    "Lasso__max_iter":[400,600,800,1000]
}

model = RandomizedSearchCV(
    model, param_grid, 
    n_iter = 10,
    cv = 3
)

#model.fit(X_train_1.head(58000),Y_train_1.head(58000))

#model.score(X_train_1.tail(2000),Y_train_1.tail(2000))

# %%
steps = [
    ('PreProcessing', PreProcessingTranformer()),
     ("scaler",Normalizer()),
    ("knn",KNeighborsRegressor())
]
model = Pipeline(steps)

param_grid = {
    "knn__n_neighbors":range(5,25,5)
}
print("gothere")
model = RandomizedSearchCV(
    model, param_grid, 
    cv = 3
)
print("gothere")

model.fit(X_train[:-2000],Y_train[:-2000])

model.score(X_train[-2000:],Y_train[-2000:])

# %%
from sklearn.model_selection import cross_val_score
from IPython.display import display

# %%
steps = [
    ('PreProcessing', PreProcessingTranformer()),
    ("scaler",Normalizer())
]

model = Pipeline(steps)

X_train_pre = model.fit_transform(X_train[:-2000], Y_train[:-2000])
X_test_pre = model.transform(X_train[-2000:])

for n in list(range(5,25,5)):
    print("n:", n)
    
    knn = KNeighborsRegressor(n_neighbors=n);
    
    knn.fit(X_train_pre, Y_train[:-2000])

    scores = knn.score(X_test_pre, Y_train[-2000:])
    display(scores)
    print("scores mean:", scores.mean())
# Out:
# n: 5
# 0.909104052146369
# scores mean: 0.909104052146369
# n: 10
# 0.8924752629390796
# scores mean: 0.8924752629390796
# n: 15
# 0.8703085702985438
# scores mean: 0.8703085702985438
# n: 20
# 0.8602181422777999
# scores mean: 0.8602181422777999

# %%
steps = [
    ('PreProcessing', PreProcessingTranformer()),
    ("scaler",Normalizer())
]

model = Pipeline(steps)

X_train_pre = model.fit_transform(X_train[:-2000], Y_train[:-2000])
X_test_pre = model.transform(X_train[-2000:])

for n in list(range(1,5+1,1)):
    print("n:", n)
    
    knn = KNeighborsRegressor(n_neighbors=n);
    
    knn.fit(X_train_pre, Y_train[:-2000])

    scores = knn.score(X_test_pre, Y_train[-2000:])
    display(scores)
    print("scores mean:", scores.mean())
# Out:
# n: 1
# 0.8836145380543288
# scores mean: 0.8836145380543288
# n: 2
# 0.9172357112348117
# scores mean: 0.9172357112348117
# n: 3
# 0.9061383218626009
# scores mean: 0.9061383218626009
# n: 4
# 0.9030969447161099
# scores mean: 0.9030969447161099
# n: 5
# 0.909104052146369
# scores mean: 0.909104052146369

# %%
steps = [
    ('PreProcessing', PreProcessingTranformer()),
    ("scaler",Normalizer())
]

model = Pipeline(steps)

X_train_pre = model.fit_transform(X_train[:-2000], Y_train[:-2000])
X_test_pre = model.transform(X_train[-2000:])

knn = KNeighborsRegressor(n_neighbors=2);
    
knn.fit(X_train_pre, Y_train[:-2000])

scores = knn.score(X_test_pre, Y_train[-2000:])
display(scores)
print("scores mean:", scores.mean())
# Out:
# 0.9172357112348117
# scores mean: 0.9172357112348117

# %%
class lior_dummy_estimator():
    def __init__(self):
        self.Mean_table = pd.DataFrame()
        self.mean = 0
    def fit(self, x, y):
        self.Mean_table = x.join(y).groupby(["Store","Dept"]).agg({"Weekly_Sales":"mean"})
        self.mean = y.values.mean()
    def predict(self, X):
        def estimated_mean(x):
            if ((x["Store"],x["Dept"]) in  self.Mean_table.index) :
                return self.Mean_table.loc[(x["Store"],x["Dept"])]
            return self.mean
        return X.apply(lambda x:estimated_mean(x) ,axis=1)
    def score (self,X,Y):
        return r2_score(Y,self.predict(X))
estimator = lior_dummy_estimator()

estimator.fit(X_train[:-2000], Y_train[:-2000])

score = estimator.score(X_train[-2000:], Y_train[-2000:])
print("score:", score)
# Out:
# score: 0.9612895517096298

# %% [markdown]
# # Final Test

# %%
steps = [
    ('PreProcessing', PreProcessingTranformer()),
    ("scaler",Normalizer()),
    ("knn", KNeighborsRegressor(n_neighbors=2))
]

model = Pipeline(steps)

model.fit(X_train, Y_train)

score = model.score(X_final_test, Y_final_test)
print("score:", score)
# Out:
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py:488: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - Date
# Feature names must be in the same order as they were in fit.
#
#   warnings.warn(message, FutureWarning)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_19052/2160595944.py in <module>
#       9 model.fit(X_train, Y_train)
#      10
# ---> 11 score = model.score(X_final_test, Y_final_test)
#      12 print("score:", score)
#
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     111
#     112             # lambda, but not partial, allows help() to work with update_wrapper
# --> 113             out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)  # noqa
#     114         else:
#     115
#
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\sklearn\pipeline.py in score(self, X, y, sample_weight)
#     705         Xt = X
#     706         for _, name, transform in self._iter(with_final=False):
# --> 707             Xt = transform.transform(Xt)
#     708         score_params = {}
#     709         if sample_weight is not None:
#
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\sklearn\preprocessing\_data.py in transform(self, X, copy)
#    1952         """
#    1953         copy = copy if copy is not None else self.copy
# -> 1954         X = self._validate_data(X, accept_sparse="csr", reset=False)
#    1955         return normalize(X, norm=self.norm, axis=1, copy=copy)
#    1956
#
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     559             raise ValueError("Validation should be done on X, y or both.")
#     560         elif not no_val_X and no_val_y:
# --> 561             X = check_array(X, **check_params)
#     562             out = X
#     563         elif no_val_X and not no_val_y:
#
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     736                     array = array.astype(dtype, casting="unsafe", copy=False)
#     737                 else:
# --> 738                     array = np.asarray(array, order=order, dtype=dtype)
#     739             except ComplexWarning as complex_warning:
#     740                 raise ValueError(
#
# c:\users\omer2\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __array__(self, dtype)
#    1991
#    1992     def __array__(self, dtype: NpDtype | None = None) -> np.ndarray:
# -> 1993         return np.asarray(self._values, dtype=dtype)
#    1994
#    1995     def __array_wrap__(
#
# TypeError: float() argument must be a string or a number, not 'Timestamp'

# %%
class lior_dummy_estimator():
    def __init__(self):
        self.Mean_table = pd.DataFrame()
        self.mean = 0
    def fit(self, x, y):
        self.Mean_table = x.join(y).groupby(["Store","Dept"]).agg({"Weekly_Sales":"mean"})
        self.mean = y.values.mean()
    def predict(self, X):
        def estimated_mean(x):
            if ((x["Store"],x["Dept"]) in  self.Mean_table.index) :
                return self.Mean_table.loc[(x["Store"],x["Dept"])]
            return self.mean
        return X.apply(lambda x:estimated_mean(x) ,axis=1)
    def score (self,X,Y):
        return r2_score(Y,self.predict(X))
estimator = lior_dummy_estimator()

estimator.fit(X_train, Y_train)

score = estimator.score(X_final_test, Y_final_test)
print("score:", score)
